# %% [markdown]
# # Assignment 1: Python Fundamentals, NumPy, and Pandas
#
# ---

# %% [markdown]
# ## Submission Instructions
#
# Submit only a link to the folder for Assignment 1 in your personal GitHub repository. Within the repository, you should have a Jupyter notebook file titled e.g. `assignment1.ipynb` or something similar.
#
# Make sure the repository is public.
#
# **Submissions must be made using a GitHub repository. Submissions that do not follow this instruction will receive 0 points.**
#
# **Late submissions are not accepted as the peer review system does not allow adding submissions past the deadline. Submit your work early to not miss the deadline!**

# %% [markdown]
# ## Code Quality
#
# Write your code so that it is pleasant to read and easy to understand. This includes:
#
# - Use descriptive variable and function names.
# - Add brief comments where the logic is not immediately obvious.
# - Keep your notebook organized with clear separation between tasks.

# %% [markdown]
# ## Grading
#
# This assignment is worth 10 points. Task 0 is worth 2 points, and tasks 1-8 are worth 1 point each.
#
# In tasks 1-8, points are given only for code that runs. If the code does not run, the task will automatically receive 0 points even if the code is almost correct.
#
# ---

# %% [markdown]
# ## Tasks

# %% [markdown]
# ### Task 0: GitHub and Jupyter Notebook for submission (2p)
#
# Set up a public GitHub repository with the following folder structure:
#
# ```
# your-repo-name/
# └── assignments/
#     └── assignment1/
#         └── assignment1.ipynb
# ```
#
# Your submission for this assignment is the Jupyter notebook file placed inside the `assignments/assignment1/` folder. The repository must be public so that the peer reviewers and the instructor can access it. (1p)
#
# The submission should be a clean, well-organized Jupyter notebook that is easy to follow. This means clear separation between tasks, meaningful markdown headings or comments for each task, and no unnecessary clutter. (1p)

# %% [markdown]
# ### Task 1: A list of dictionaries (1p)
#
# You are given a list of raw transaction records, where each record is a dictionary:
#
# ```python
# transactions = [
#     {"id": 1, "product": "Laptop", "price": 1200, "quantity": 2, "region": "EU"},
#     {"id": 2, "product": "Phone", "price": 800, "quantity": -1, "region": "US"},
#     {"id": 3, "product": "Tablet", "price": 0, "quantity": 5, "region": "EU"},
#     {"id": 4, "product": "Monitor", "price": 350, "quantity": 3, "region": "US"},
#     {"id": 5, "product": "Laptop", "price": 1200, "quantity": 1, "region": "EU"},
#     {"id": 6, "product": "Keyboard", "price": 75, "quantity": 10, "region": "APAC"},
# ]
# ```
#
# Write a script that performs the following steps:
#
# a) Filter out invalid transactions where the price is zero or the quantity is negative.
#
# b) For each remaining transaction, compute a new field `total` = `price * quantity`.
#
# c) Group the valid transactions by `region` and compute the total revenue per region. Store the result in a dictionary.
#
# d) Print the region with the highest total revenue and its value using an f-string.

# %%
#a)
transactions = [
    {"id": 1, "product": "Laptop", "price": 1200, "quantity": 2, "region": "EU"},
    {"id": 2, "product": "Phone", "price": 800, "quantity": -1, "region": "US"},
    {"id": 3, "product": "Tablet", "price": 0, "quantity": 5, "region": "EU"},
    {"id": 4, "product": "Monitor", "price": 350, "quantity": 3, "region": "US"},
    {"id": 5, "product": "Laptop", "price": 1200, "quantity": 1, "region": "EU"},
    {"id": 6, "product": "Keyboard", "price": 75, "quantity": 10, "region": "APAC"},
]

transactions_valid = []
for transaction in transactions:
    if transaction["price"] > 0 and transaction["quantity"] >= 0:
        transactions_valid.append(transaction)

#new list created with only valid transactions by using a for loop to iterate over the transactions list 
#and checking if each transaction is valid -> valid transactions are appended to a new list

# %%
#b)
for transaction in transactions_valid:
    transaction["total"] = transaction["price"] * transaction["quantity"]
print(transactions_valid)   #for visualization
#total is now added for each transaction using a for loop
# Out:
# [{'id': 1, 'product': 'Laptop', 'price': 1200, 'quantity': 2, 'region': 'EU', 'total': 2400}, {'id': 4, 'product': 'Monitor', 'price': 350, 'quantity': 3, 'region': 'US', 'total': 1050}, {'id': 5, 'product': 'Laptop', 'price': 1200, 'quantity': 1, 'region': 'EU', 'total': 1200}, {'id': 6, 'product': 'Keyboard', 'price': 75, 'quantity': 10, 'region': 'APAC', 'total': 750}]

# %%
#c)
EU_transactions = []
US_transactions = []
APAC_transactions = []


for transaction in transactions_valid:
    if transaction["region"] == "EU":
        EU_transactions.append(transaction)
    if transaction["region"] == "US":
        US_transactions.append(transaction)
    if transaction["region"] == "APAC":
        APAC_transactions.append(transaction)

EU_revenue = 0
for transaction in EU_transactions:
    EU_revenue = EU_revenue + transaction["total"]
US_revenue = 0
for transaction in US_transactions:
    US_revenue = US_revenue + transaction["total"]
APAC_revenue = 0
for transaction in APAC_transactions:
    APAC_revenue = APAC_revenue + transaction["total"]

region_revenues = {"EU": EU_revenue, "US": US_revenue, "APAC": APAC_revenue}
region_revenues
# Out:
# {'EU': 3600, 'US': 1050, 'APAC': 750}

# %%
revenue_region = {}

for transaction in transactions_valid:
    if transaction["region"] not in revenue_region:
        revenue_region[transaction["region"]] = transaction["total"]
    else:
        revenue_region[transaction["region"]] = revenue_region[transaction["region"]] + transaction["total"]

print(revenue_region)
# Out:
# {'EU': 3600, 'US': 1050, 'APAC': 750}

# %%
#d)
highest_revenue = max(region_revenues, key = region_revenues.get)
print(f" The region with the highest revenue: {highest_revenue}")
# Out:
#  The region with the highest revenue: EU

# %% [markdown]
# ### Task 2: Creating a function (1p)
#
# You are given the following list of daily sales figures (in euros) for a two-week period:
#
# ```python
# sales = [1200, 980, 1540, 870, 2010, 1650, 1300, 1100, 950, 1780, 2200, 1430, 1600, 1900]
# ```
#
# Write a function called `summarise_sales` that takes a list of daily sales values and returns a dictionary containing:
#
# `"total"`: the sum of all daily sales
#
# `"average"`: the mean daily sales value, rounded to two decimals
#
# `"best_day"`: the index (starting from 1) of the day with the highest sales
#
# `"worst_day"`: the index (starting from 1) of the day with the lowest sales
#
# `"above_average_count"`: the number of days where sales exceeded the average
#
# Call the function with the list above and print the returned dictionary.

# %%
sales = [1200, 980, 1540, 870, 2010, 1650, 1300, 1100, 950, 1780, 2200, 1430, 1600, 1900]

def summarise_sales(sales):
    total = sum(sales)
    average = round((sum(sales))/(len(sales)), 2)
    best_day = sales.index(max(sales)) + 1
    worst_day = sales.index(min(sales)) + 1
    above_average_count = 0
    for sale in sales: 
        if sale > above_average_count:
            above_average_count =  above_average_count + 1
    return {"total": total, "average": average, "best_day": best_day, "worst_day": worst_day, "above_average_count": above_average_count}

print(summarise_sales(sales))
# Out:
# {'total': 20510, 'average': 1465.0, 'best_day': 11, 'worst_day': 4, 'above_average_count': 14}

# %% [markdown]
# ### Task 3: Loops (1p)
#
# You are given the following list of student records:
#
# ```python
# students = [
#     {"name": "Anna", "grade": 85, "attendance": 0.92},
#     {"name": "Erik", "grade": 58, "attendance": 0.75},
#     {"name": "Mia", "grade": 91, "attendance": 0.98},
#     {"name": "Leo", "grade": 44, "attendance": 0.60},
#     {"name": "Sara", "grade": 72, "attendance": 0.88},
#     {"name": "Tom", "grade": 67, "attendance": 0.70},
#     {"name": "Nina", "grade": 95, "attendance": 0.99},
#     {"name": "Olli", "grade": 50, "attendance": 0.65},
# ]
# ```
#
# Using `for` loops and `if` statements, perform the following:
#
# a) Create a new list called `passing` that contains only the names of students with a grade of 50 or above. Print the list.
#
# b) Loop through the students and print a status message for each. If the student's grade is 80 or above, print `"[name]: Excellent"`; if between 50 and 79, print `"[name]: Pass"`; otherwise print `"[name]: Fail"`.
#
# c) Count how many students have an attendance rate below 0.80. Print the count.
#
# d) Find the student with the highest grade using a loop (do not use `max()`). Print the student's name and grade.
#
# e) Now find the student with the highest grade using `max()`. Print the student's name and grade.

# %%
students = [
    {"name": "Anna", "grade": 85, "attendance": 0.92},
    {"name": "Erik", "grade": 58, "attendance": 0.75},
    {"name": "Mia", "grade": 91, "attendance": 0.98},
    {"name": "Leo", "grade": 44, "attendance": 0.60},
    {"name": "Sara", "grade": 72, "attendance": 0.88},
    {"name": "Tom", "grade": 67, "attendance": 0.70},
    {"name": "Nina", "grade": 95, "attendance": 0.99},
    {"name": "Olli", "grade": 50, "attendance": 0.65},
]

#a)
passing = []

for student in students:
    if student["grade"] >= 50:
        passing.append(student["name"])
print(passing)
# Out:
# ['Anna', 'Erik', 'Mia', 'Sara', 'Tom', 'Nina', 'Olli']

# %%
#b)

for student in students:
    if student["grade"] >= 80:
        status = f"{student["name"]}: Excellent"
    if (student["grade"] < 80) and (student["grade"] >= 50):
        status = f"{student["name"]}: Pass"
    if student["grade"] < 50:
        status = f"{student["name"]}: Fail"    
    print(status)
# Out:
# Anna: Excellent
# Erik: Pass
# Mia: Excellent
# Leo: Fail
# Sara: Pass
# Tom: Pass
# Nina: Excellent
# Olli: Pass

# %%
#c)
attendance_over_80 = 0
for student in students:
    if student["attendance"] >= 0.80:
        attendance_over_80 = attendance_over_80 + 1
print(attendance_over_80)
# Out:
# 4

# %%
#d)
highest_grade = 0
student_name = 0
for student in students:
    if student["grade"] > highest_grade:
        highest_grade = student["grade"]
        student_name = student["name"]
print(f"Student with the highest grade: {student_name}, grade: {highest_grade}")
# Out:
# Student with the highest grade: Nina, grade: 95

# %%
#e)
max_grade = max(student["grade"] for student in students)
best_student = [student["name"] for student in students if student["grade"] == max_grade][0]
print(f" Student with the highest grade: {best_student}, grade: {max_grade}")
# Out:
#  Student with the highest grade: Nina, grade: 95

# %% [markdown]
# ### Task 4: Class and methods (1p)
#
# Design a class called `Portfolio` that represents an investment portfolio. The constructor is provided for you:
#
# ```python
# class Portfolio:
#     def __init__(self, owner):
#         self.owner = owner
#         self.holdings = {}  # ticker -> {shares, price_per_share}
# ```
#
# Each key in `holdings` is a ticker symbol (string) and each value is a dictionary with keys `"shares"` and `"price_per_share"`. Add the following methods to the class:
#
# a) A method `add_asset(ticker, shares, price_per_share)` that adds a new asset or updates the number of shares if the ticker already exists (in which case the price should also be updated).
#
# b) A method `total_value()` that returns the total market value of the portfolio.
#
# c) A method `most_valuable()` that returns the ticker of the asset with the highest total value (shares × price).
#
# d) A `__str__` method that returns a readable summary of the portfolio, including the owner's name, the number of assets, and the total value.
#
# Create an instance, add at least three assets, and demonstrate all methods with printed output.

# %%
class Portfolio:
    def __init__(self, owner):
        self.owner = owner
        self.holdings = {}
#a)
    def add_asset(self, ticker, shares, price_per_share): 
        if ticker in self.holdings:
            self.holdings[ticker]["shares"] = shares
            self.holdings[ticker]["price_per_share"] = price_per_share
        else:
            self.holdings[ticker] = {"shares" : shares, "price_per_share": price_per_share}
#b)   
    def total_value(self):                                
        total_value = 0
        for holdings in self.holdings:
            holding_value = self.holdings[holdings]["shares"] * self.holdings[holdings]["price_per_share"]
            total_value = total_value + holding_value
        return total_value
#c)      
    def most_valuable(self):                             
        most_valuable = 0
        for holdings in self.holdings:
            if self.holdings[holdings]["shares"] * self.holdings[holdings]["price_per_share"] > most_valuable:
                most_valuable = self.holdings[holdings]["shares"] * self.holdings[holdings]["price_per_share"]
                ticker = holdings
        return ticker
#d)
    def __str__(self):
        summary = f"Summary: Owner's name: {self.owner}, Number of assets: {len(self.holdings)}, Total value: {self.total_value()}"
        return summary

portfolio = Portfolio("Kristian")
portfolio.add_asset("NVDA", 50, 4.53)
portfolio.add_asset("MSFT", 32, 6.42)
portfolio.add_asset("AAPL", 10, 3.68)

print(f"Portfolio holdings after adding new assets: {portfolio.holdings}")
print()

print(f"The total portfolio value is {portfolio.total_value()}")
print()

print(f"The most valuable asset in the portfolio is {portfolio.most_valuable()}")
print()

print(portfolio)
print()
# Out:
# Portfolio holdings after adding new assets: {'NVDA': {'shares': 50, 'price_per_share': 4.53}, 'MSFT': {'shares': 32, 'price_per_share': 6.42}, 'AAPL': {'shares': 10, 'price_per_share': 3.68}}
#
# The total portfolio value is 468.74
#
# The most valuable asset in the portfolio is NVDA
#
# Summary: Owner's name: Kristian, Number of assets: 3, Total value: 468.74

# %% [markdown]
# ### Task 5: Importing a module (1p)
#
# You are given the following list of order dates (as strings) and product names:
#
# ```python
# orders = [
#     ("2025-01-15", "Laptop"), ("2025-01-22", "Phone"),
#     ("2025-02-03", "Laptop"), ("2025-02-14", "Tablet"),
#     ("2025-03-01", "Phone"), ("2025-03-10", "Phone"),
#     ("2025-03-22", "Laptop"), ("2025-04-05", "Monitor"),
# ]
# ```
#
# Using the `datetime` module, parse each date string into a `datetime.date` object. Compute and print the number of days between the earliest and latest order.

# %%
import datetime
orders = [
    ("2025-01-15", "Laptop"), ("2025-01-22", "Phone"),
    ("2025-02-03", "Laptop"), ("2025-02-14", "Tablet"),
    ("2025-03-01", "Phone"), ("2025-03-10", "Phone"),
    ("2025-03-22", "Laptop"), ("2025-04-05", "Monitor"),
]

dates = []
for order in orders:
    dates.append(datetime.datetime.strptime(order[0], "%Y-%m-%d").date())
#made a new list with datetime.date objects of the dates

print(f"Days between the earliest and the latest order: {max(dates)-min(dates)}")
# Out:
# Days between the earliest and the latest order: 80 days, 0:00:00

# %% [markdown]
# ### Task 6: Array Operations and Broadcasting (1p)
#
# A company tracks quarterly revenue (in thousands of euros) across four quarters over three years:
#
# ```python
# # Rows: years (2022, 2023, 2024), Columns: quarters (Q1, Q2, Q3, Q4)
# revenue = np.array([
#     [210, 230, 190, 250],
#     [220, 260, 200, 270],
#     [250, 290, 230, 310]])
# ```
#
# a) Compute and print the total annual revenue for each year (i.e., row sums). Use the `axis` parameter.
#
# b) Compute the mean quarterly revenue across all years (i.e., column means).
#
# c) Using broadcasting, apply a growth adjustment to the 2024 row by multiplying it element-wise with the array `[1.05, 1.03, 1.08, 1.02]`. Print the adjusted values.
#
# d) Use boolean indexing to find and print all quarterly revenue values that exceed 250 (thousands of euros).

# %%
import numpy as np

revenue = np.array([
    [210, 230, 190, 250],
    [220, 260, 200, 270],
    [250, 290, 230, 310]])
#a)
annual_revenues = revenue.sum(axis=1)
print(f" Revenue for 2022: {annual_revenues[0]}k euros")
print(f" Revenue for 2023: {annual_revenues[1]}k euros")
print(f" Revenue for 2024: {annual_revenues[2]}k euros")
# Out:
#  Revenue for 2022: 880k euros
#  Revenue for 2023: 950k euros
#  Revenue for 2024: 1080k euros

# %%
#b)
mean_quarterly_revenues = revenue.sum(axis=0) / revenue.shape[0]

print(f" Mean first quarter revenue: {mean_quarterly_revenues[0]}k euros")
print(f" Mean second quarter revenue: {mean_quarterly_revenues[1]}k euros")
print(f" Mean third quarter revenue: {mean_quarterly_revenues[2]}k euros")
print(f" Mean fourth quarter revenue: {mean_quarterly_revenues[3]}k euros")
# Out:
#  Mean first quarter revenue: 226.66666666666666k euros
#  Mean second quarter revenue: 260.0k euros
#  Mean third quarter revenue: 206.66666666666666k euros
#  Mean fourth quarter revenue: 276.6666666666667k euros

# %%
#c)
revenue2024 = revenue[2]
adjust_array = np.array([1.05, 1.03, 1.08, 1.02])
revenue2024_adjusted = revenue2024 * adjust_array
print(f"Adjusted quarterly revenue for 2024 is: {revenue2024_adjusted}")
# Out:
# Adjusted quarterly revenue for 2024 is: [262.5 298.7 248.4 316.2]

# %%
#d)
boolean_mask = revenue > 250
print(f" Quarterly revenue values exceeding 250k euros: {revenue[boolean_mask]}")
# Out:
#  Quarterly revenue values exceeding 250k euros: [260 270 290 310]

# %% [markdown]
# ### Task 7: Pandas (1p)
#
# Create the following DataFrame:
#
# ```python
# data = {
#     "employee": ["Anna", "Erik", "Mia", "Leo", "Sara", "Tom"],
#     "department": ["Finance", "Marketing", "Finance", "IT", "Marketing", "IT"],
#     "salary": [4500, 4000, 4800, 5200, 3900, 5100],
#     "years_exp": [5, 3, 7, 10, 2, 8],
#     "performance_score": [4.2, 3.8, 4.5, 4.0, 3.5, 4.9]
# }
# ```
#
# a) Add a new column `salary_per_year_exp` computed as `salary / years_exp`. Round to the nearest integer.
#
# b) Sort the DataFrame by `performance_score` in descending order and print the top 3 employees.
#
# c) Using `.loc`, select all employees in the Finance department with a performance score above 4.0. Print the result.
#
# d) Rename the column `years_exp` to `experience_years` using the `.rename()` method.
#
# e) Using `.iloc`, select and print the salary and performance score columns for the first four employees.

# %%
import numpy as np
import pandas as pd
data = {
    "employee": ["Anna", "Erik", "Mia", "Leo", "Sara", "Tom"],
    "department": ["Finance", "Marketing", "Finance", "IT", "Marketing", "IT"],
    "salary": [4500, 4000, 4800, 5200, 3900, 5100],
    "years_exp": [5, 3, 7, 10, 2, 8],
    "performance_score": [4.2, 3.8, 4.5, 4.0, 3.5, 4.9]
}

employee_data = pd.DataFrame(data)

#a)
employee_data["salary_per_year_exp"] = round(employee_data["salary"] / employee_data["years_exp"],0)
display(employee_data)
# Out:
#   employee department  salary  years_exp  performance_score  \
# 0     Anna    Finance    4500          5                4.2
# 1     Erik  Marketing    4000          3                3.8
# 2      Mia    Finance    4800          7                4.5
# 3      Leo         IT    5200         10                4.0
# 4     Sara  Marketing    3900          2                3.5
# 5      Tom         IT    5100          8                4.9
#
#    salary_per_year_exp
# 0                900.0
# 1               1333.0
# 2                686.0
# 3                520.0
# 4               1950.0
# 5                638.0

# %%
#b)
sorted_employee_data = employee_data.sort_values(by='performance_score',ascending=False)
print(sorted_employee_data [:3])
# Out:
#   employee department  salary  years_exp  performance_score  \
# 5      Tom         IT    5100          8                4.9
# 2      Mia    Finance    4800          7                4.5
# 0     Anna    Finance    4500          5                4.2
#
#    salary_per_year_exp
# 5                638.0
# 2                686.0
# 0                900.0

# %%
#c
print(employee_data.loc[(employee_data["department"] == "Finance") & (employee_data["performance_score"] > 4)])
# Out:
#   employee department  salary  years_exp  performance_score  \
# 0     Anna    Finance    4500          5                4.2
# 2      Mia    Finance    4800          7                4.5
#
#    salary_per_year_exp
# 0                900.0
# 2                686.0

# %%
#d)
employee_data.rename(columns = {"years_exp": "experience_years"})
# Out:
#   employee department  salary  experience_years  performance_score  \
# 0     Anna    Finance    4500                 5                4.2
# 1     Erik  Marketing    4000                 3                3.8
# 2      Mia    Finance    4800                 7                4.5
# 3      Leo         IT    5200                10                4.0
# 4     Sara  Marketing    3900                 2                3.5
# 5      Tom         IT    5100                 8                4.9
#
#    salary_per_year_exp
# 0                900.0
# 1               1333.0
# 2                686.0
# 3                520.0
# 4               1950.0
# 5                638.0

# %%
#e)
salary_perf4 = employee_data.iloc[:4,[2, 4]]
print(salary_perf4)
# Out:
#    salary  performance_score
# 0    4500                4.2
# 1    4000                3.8
# 2    4800                4.5
# 3    5200                4.0

# %% [markdown]
# ### Task 8: More Pandas (1p)
#
# A company records daily website traffic over four weeks. Generate the data by running the following script first:
#
# ```python
# import numpy as np
# import pandas as pd
#
# rng = np.random.default_rng(seed=123)
# days = pd.date_range(start="2025-01-06", periods=28, freq="D")
# visitors = rng.integers(200, 600, size=28)
# conversion_rate = rng.uniform(0.02, 0.08, size=28).round(4)
# avg_order_value = rng.normal(50, 10, size=28).round(2)
# ```
#
# Using this generated data, perform the following:
#
# a) Create a DataFrame with columns: `date`, `visitors`, `conversion_rate`, and `avg_order_value`. Set `date` as the index.
#
# b) Compute two new columns: `conversions` (= visitors × conversion_rate, rounded to the nearest integer) and `daily_revenue` (= conversions × avg_order_value).

# %%
import numpy as np
import pandas as pd

rng = np.random.default_rng(seed=123)
days = pd.date_range(start="2025-01-06", periods=28, freq="D")
visitors = rng.integers(200, 600, size=28)
conversion_rate = rng.uniform(0.02, 0.08, size=28).round(4)
avg_order_value = rng.normal(50, 10, size=28).round(2)

#a)
website_data = {"date": days,
"visitors": visitors,
"conversion_rate": conversion_rate,
"avg_order_value": avg_order_value}


website_traffic = pd.DataFrame(website_data).set_index("date") 
display(website_traffic)
# Out:
#             visitors  conversion_rate  avg_order_value
# date
# 2025-01-06       206           0.0645            64.30
# 2025-01-07       472           0.0578            48.44
# 2025-01-08       437           0.0756            43.26
# 2025-01-09       221           0.0339            43.61
# 2025-01-10       563           0.0679            49.39
# 2025-01-11       288           0.0511            46.07
# 2025-01-12       302           0.0339            72.90
# 2025-01-13       273           0.0300            42.82
# 2025-01-14       333           0.0499            50.33
# 2025-01-15       270           0.0550            50.28
# 2025-01-16       339           0.0311            50.28
# 2025-01-17       524           0.0209            50.55
# 2025-01-18       380           0.0483            45.18
# 2025-01-19       569           0.0637            44.17
# 2025-01-20       379           0.0751            41.38
# 2025-01-21       310           0.0575            35.12
# 2025-01-22       515           0.0750            52.16
# 2025-01-23       527           0.0719            59.84
# 2025-01-24       544           0.0331            44.57
# 2025-01-25       555           0.0720            44.41
# 2025-01-26       210           0.0638            46.84
# 2025-01-27       405           0.0367            45.39
# 2025-01-28       307           0.0678            35.64
# 2025-01-29       297           0.0719            63.65
# 2025-01-30       296           0.0380            54.39
# 2025-01-31       529           0.0516            42.88
# 2025-02-01       516           0.0243            52.97
# 2025-02-02       285           0.0550            45.62

# %%
#b)
website_traffic["conversions"] = website_traffic["visitors"] * website_traffic["conversion_rate"]
website_traffic["daily_revenue"] = website_traffic["conversions"] * website_traffic["avg_order_value"]
display(website_traffic)
# Out:
#             visitors  conversion_rate  avg_order_value  conversions  \
# date
# 2025-01-06       206           0.0645            64.30      13.2870
# 2025-01-07       472           0.0578            48.44      27.2816
# 2025-01-08       437           0.0756            43.26      33.0372
# 2025-01-09       221           0.0339            43.61       7.4919
# 2025-01-10       563           0.0679            49.39      38.2277
# 2025-01-11       288           0.0511            46.07      14.7168
# 2025-01-12       302           0.0339            72.90      10.2378
# 2025-01-13       273           0.0300            42.82       8.1900
# 2025-01-14       333           0.0499            50.33      16.6167
# 2025-01-15       270           0.0550            50.28      14.8500
# 2025-01-16       339           0.0311            50.28      10.5429
# 2025-01-17       524           0.0209            50.55      10.9516
# 2025-01-18       380           0.0483            45.18      18.3540
# 2025-01-19       569           0.0637            44.17      36.2453
# 2025-01-20       379           0.0751            41.38      28.4629
# 2025-01-21       310           0.0575            35.12      17.8250
# 2025-01-22       515           0.0750            52.16      38.6250
# 2025-01-23       527           0.0719            59.84      37.8913
# 2025-01-24       544           0.0331            44.57      18.0064
# 2025-01-25       555           0.0720            44.41      39.9600
# 2025-01-26       210           0.0638            46.84      13.3980
# 2025-01-27       405           0.0367            45.39      14.8635
# 2025-01-28       307           0.0678            35.64      20.8146
# 2025-01-29       297           0.0719            63.65      21.3543
# 2025-01-30       296           0.0380            54.39      11.2480
# 2025-01-31       529           0.0516            42.88      27.2964
# 2025-02-01       516           0.0243            52.97      12.5388
# 2025-02-02       285           0.0550            45.62      15.6750
#
#             daily_revenue
# date
# 2025-01-06     854.354100
# 2025-01-07    1321.520704
# 2025-01-08    1429.189272
# 2025-01-09     326.721759
# 2025-01-10    1888.066103
# 2025-01-11     678.002976
# 2025-01-12     746.335620
# 2025-01-13     350.695800
# 2025-01-14     836.318511
# 2025-01-15     746.658000
# 2025-01-16     530.097012
# 2025-01-17     553.603380
# 2025-01-18     829.233720
# 2025-01-19    1600.954901
# 2025-01-20    1177.794802
# 2025-01-21     626.014000
# 2025-01-22    2014.680000
# 2025-01-23    2267.415392
# 2025-01-24     802.545248
# 2025-01-25    1774.623600
# 2025-01-26     627.562320
# 2025-01-27     674.654265
# 2025-01-28     741.832344
# 2025-01-29    1359.201195
# 2025-01-30     611.778720
# 2025-01-31    1170.469632
# 2025-02-01     664.180236
# 2025-02-02     715.093500
